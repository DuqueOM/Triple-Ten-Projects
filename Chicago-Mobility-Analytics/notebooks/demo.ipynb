# %% [markdown]
# # Chicago Mobility — Demo
# Train, predict one sample, and view metrics.

# %%
from pathlib import Path
import json
from main import train_model, load_config, setup_logging
cfg = load_config(Path('configs/default.yaml'))
setup_logging('INFO')
m = train_model(cfg, seed=42)
print(json.dumps(m, indent=2))

# %%
from app.example_load import load_model
import numpy as np
model = load_model()
X = np.array([[9.0, 5.0, 1.0, 0.0]])
float(model.predict(X)[0])
