# %% [markdown]
# # Exploratory Data Analysis — OilWell Location Optimizer
#
# Este notebook acompaña a `main.py` y se centra en: (1) lectura de datos, (2) EDA, (3) chequeos de calidad, (4) visualizaciones y (5) hallazgos clave.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
from pathlib import Path
base = Path('..').resolve().parent
df0 = pd.read_csv(base/'geo_data_0.csv')
df1 = pd.read_csv(base/'geo_data_1.csv')
df2 = pd.read_csv(base/'geo_data_2.csv')
for i, df in enumerate([df0, df1, df2]):
    print(f'Region {i}:', df.shape)
    display(df.head())
    display(df.describe())
