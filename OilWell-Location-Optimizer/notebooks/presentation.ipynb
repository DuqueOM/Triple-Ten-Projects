# %% [markdown]
# # OilWell Location Optimizer — Executive Presentation
#
# - Problema de negocio y objetivo
# - Datos y preprocesamiento
# - Modelo y métricas (RMSE)
# - Análisis de riesgo (bootstrap)
# - Recomendación de región
# - Próximos pasos
