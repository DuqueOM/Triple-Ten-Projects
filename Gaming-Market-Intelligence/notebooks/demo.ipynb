# %% [markdown]
# # Gaming Market — Demo
# Load pipeline and predict on one sample.

# %%
from app.example_load import load_pipeline
import pandas as pd
pipe = load_pipeline()
sample = {'platform':'PS4','year_of_release':2015,'genre':'Action','critic_score':85,'user_score':8.2,'rating':'M'}
df = pd.DataFrame([sample])
int(pipe.predict(df)[0])
