# %% [markdown]
# # Presentation — Gaming Market Intelligence
#
# Resumen ejecutivo, datos clave, metodología, resultados y recomendaciones.

# %% [markdown]
# ## 1. Resumen Ejecutivo
# - Predicción de éxito (ventas ≥1M) con pipeline reproducible.
# - Métricas: F1, Precision, Recall, ROC-AUC.
# - API de inferencia (FastAPI) y Docker para servir.

# %% [markdown]
# ## 2. Dataset y Preprocesamiento
# - Origen público (1980–2016).
# - Limpieza de tipos, imputación y OHE.

# %% [markdown]
# ## 3. Resultados
# - Baseline vs modelo.
# - Recomendaciones de negocio.
