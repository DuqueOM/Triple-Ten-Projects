# %% [markdown]
# # GoldRecovery — Demo
# Train on train CSV and show test sMAPE.

# %%
import json
from main import main
# training and evaluation via CLI functions not exposed; run script commands if needed
print('Use: !python main.py --mode train --config configs/config.yaml')
