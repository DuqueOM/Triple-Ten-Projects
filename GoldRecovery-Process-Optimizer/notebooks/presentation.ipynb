# %% [markdown]
# # GoldRecovery - Presentación ejecutiva
#
# ## Objetivo
# Resumen del problema, solución propuesta y resultados clave (métricas).

# %% [markdown]
# ## Resultados
# - sMAPE: ...
# - MAE: ...
# - Baseline MAE: ...

# %% [markdown]
# ## Interpretabilidad
# Ejemplos de importancia de variables y análisis de errores.
